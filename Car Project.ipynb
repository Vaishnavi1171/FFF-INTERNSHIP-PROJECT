# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle

# %%
# here %matplotlib inline helps the environment to draw the plots immediately after the current cell.

# %% [markdown]
# # LOADING THE DATASET

# %%
df = pd.read_csv("car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# first 5 rows of the dataset
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# last 5 rows of the dataset
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# number of rows and columns
df.shape
# Out:
# (301, 9)

# %%
r, c = df.shape
print("Total no. of rows : ", r)
print("Total no. of columns : ", c)
# Out:
# Total no. of rows :  301
# Total no. of columns :  9

# %%
# information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# statistical info of the dataset
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# here first is 'count' shows how mmany rows have non-missing values
# second is 'mean' it gives us the average
# third is 'std' (standard deviation) this show how numerically spread out the values are
# fourth is 'min' shows the smallest value
# '25%', '50%', '75%' show us the quarter way through the list
# 'max' is the largest number

# %%
# to check if there are null values in the dataset
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# column names
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# to check if there are duplicate values in the dataset
df.duplicated().sum()
# Out:
# 2

# %%
df.duplicated(subset=['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df.loc[df.duplicated(), :]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0

# %%
# deleting the duplicate values of the dataset
df.drop_duplicates(inplace=True)
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# checkinng if the duplicate values are permanently deleted from the dataset
df.iloc[15:95]
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 15         ertiga  2016           7.75          10.79       43000    Diesel
# 16         ertiga  2015           7.25          10.79       41678    Diesel
# 18        wagon r  2015           3.25           5.09       35500       CNG
# 19            sx4  2010           2.65           7.98       41442    Petrol
# 20       alto k10  2016           2.85           3.95       25000    Petrol
# ..            ...   ...            ...            ...         ...       ...
# 91         innova  2014          11.25          16.09       58242    Diesel
# 92         innova  2005           3.51          13.70       75000    Petrol
# 94  corolla altis  2008           4.00          22.78       89000    Petrol
# 95  corolla altis  2012           5.85          18.61       72000    Petrol
# 96         innova  2016          20.75          25.39       29000    Diesel
#
#    Seller_Type Transmission  Owner
# ...

# %%
df.shape
# Out:
# (299, 9)

# %%
# we need to find selling price, so we are taking unique values of the categorical features

# %%
(df['Seller_Type'].unique())
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
(df['Fuel_Type'].unique())
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
(df['Transmission'].unique())
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
(df['Owner'].unique())
# Out:
# array([0, 1, 3], dtype=int64)

# %%
unique = df.nunique()
unique
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df.Seller_Type.value_counts()
# Out:
# Dealer        193
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
#Plot the unique values

sns.countplot(df['Seller_Type'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seller_Type', ylabel='count'>

# %%
df.Fuel_Type.value_counts()
# Out:
# Petrol    239
# Diesel     58
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
sns.countplot(df['Fuel_Type'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %%
df.Transmission.value_counts()
# Out:
# Manual       260
# Automatic     39
# Name: Transmission, dtype: int64

# %%
sns.countplot(df['Transmission'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %%
df.Owner.value_counts()
# Out:
# 0    288
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
sns.countplot(df['Owner'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Owner', ylabel='count'>

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
# to create a new derived feature

# %%
# to find selling price we need to create a new derived feature

# %%
final_dataset = df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type',
                    'Transmission','Owner']]

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
# finding catgorical and numerical features
categorical_features = final_dataset.select_dtypes(object)
categorical_features
# Out:
#     Fuel_Type Seller_Type Transmission
# 0      Petrol      Dealer       Manual
# 1      Diesel      Dealer       Manual
# 2      Petrol      Dealer       Manual
# 3      Petrol      Dealer       Manual
# 4      Diesel      Dealer       Manual
# ..        ...         ...          ...
# 296    Diesel      Dealer       Manual
# 297    Petrol      Dealer       Manual
# 298    Petrol      Dealer       Manual
# 299    Diesel      Dealer       Manual
# 300    Petrol      Dealer       Manual
#
# [299 rows x 3 columns]

# %%
numerical_features = final_dataset.select_dtypes(int,float)
numerical_features
# Out:
#      Year  Kms_Driven  Owner
# 0    2014       27000      0
# 1    2013       43000      0
# 2    2017        6900      0
# 3    2011        5200      0
# 4    2014       42450      0
# ..    ...         ...    ...
# 296  2016       33988      0
# 297  2015       60000      0
# 298  2009       87934      0
# 299  2017        9000      0
# 300  2016        5464      0
#
# [299 rows x 3 columns]

# %%
# to create a new feature or column we can simply write the below code

# %%
final_dataset['Current_Year']= 2023

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2023
# 1       Manual      0          2023
# 2       Manual      0          2023
# 3       Manual      0          2023
# 4       Manual      0          2023

# %%
final_dataset['Number_of_years']=final_dataset['Current_Year']-final_dataset['Year']
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  Number_of_years
# 0       Manual      0          2023                9
# 1       Manual      0          2023               10
# 2       Manual      0          2023                6
# 3       Manual      0          2023               12
# 4       Manual      0          2023                9

# %%
# as we got Number_of_years we don't need 'Year' feature so we will drop it permanently
final_dataset.drop(['Year'], axis = 1, inplace=True)
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year  Number_of_years
# 0         Manual      0          2023                9
# ...

# %%
# 'inplace = True' is used to permanently delete the feature from the dataset

# %%
# in the same way we will also delete the 'Current_Year' feature

# %%
final_dataset.drop(['Current_Year'], axis = 1, inplace = True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Number_of_years
# 0       Manual      0                9
# 1       Manual      0               10
# 2       Manual      0                6
# 3       Manual      0               12
# 4       Manual      0                9

# %%
final_dataset = pd.get_dummies(final_dataset, drop_first=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Number_of_years  \
# 0           3.35           5.59       27000      0                9
# 1           4.75           9.54       43000      0               10
# 2           7.25           9.85        6900      0                6
# 3           2.85           4.15        5200      0               12
# 4           4.60           6.87       42450      0                9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
# get_dummies is a function in pandas 
# it is used to convert some features of the dataset into other values

# %%
# as we see that we got seperate features of fuel type 'petrol' and 'diesel' when 'petrol' and 'diesel' is 0 it represents 'CNG'

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.876378    0.028566 -0.087880
# Present_Price                0.876378       1.000000    0.205253  0.009947
# Kms_Driven                   0.028566       0.205253    1.000000  0.089367
# Owner                       -0.087880       0.009947    0.089367  1.000000
# Number_of_years             -0.234369       0.053563    0.525714  0.181639
# Fuel_Type_Diesel             0.543541       0.464849    0.173295 -0.051836
# Fuel_Type_Petrol            -0.531636      -0.456746   -0.173595  0.054102
# Seller_Type_Individual      -0.553851      -0.511686   -0.101030  0.123646
# Transmission_Manual         -0.348869      -0.334265   -0.163881 -0.052166
#
#                         Number_of_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                 -0.234369          0.543541         -0.531636
# ...

# %%
# to plot a pairplot of the final_dataset
sns.pairplot(final_dataset)

# %%
corrmat = final_dataset.corr()
top_corr_features= corrmat.index
plt.figure(figsize=(10,10))
sns.heatmap(final_dataset[top_corr_features].corr(), annot=True, cmap="RdYlGn")
plt.show()

# %%
# 'cmap = RdYlGn' is used to style the heatmap

# %%
# here we see that the green color is highly positively correlated and red color is highly negatiely 
# correlated.
# basically heatmap helps us check the correlation.

# %%
# these are the independent and dependent features below

# %%
X = final_dataset.iloc[:,1:]

# %%
Y = final_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Number_of_years  Fuel_Type_Diesel  \
# 0           5.59       27000      0                9                 0
# 1           9.54       43000      0               10                 1
# 2           9.85        6900      0                6                 0
# 3           4.15        5200      0               12                 0
# 4           6.87       42450      0                9                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Number_of_years  \
# 0           3.35           5.59       27000      0                9
# 1           4.75           9.54       43000      0               10
# 2           7.25           9.85        6900      0                6
# 3           2.85           4.15        5200      0               12
# 4           4.60           6.87       42450      0                9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
# to find important features we can use sklearn

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.10591916e-01 3.97085718e-02 3.18709098e-04 8.54330086e-02
#  8.47408798e-02 2.87950983e-02 2.58266215e-01 9.21456017e-02]

# %%
feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances.nlargest(5).plot(kind='bar')
plt.show()

# %%
# to split our data and be able to classify it we can use the below code

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#      Present_Price  Kms_Driven  Owner  Number_of_years  Fuel_Type_Diesel  \
# 194          0.787       50000      0               15                 0
# 277         13.600       21780      0                8                 0
# 115          1.470       17500      0                8                 0
# 141          0.800       20000      0                7                 0
# 58           6.800       39485      1                9                 0
# ..             ...         ...    ...              ...               ...
# 24           4.410       56879      0               10                 0
# 85          23.730      142000      3               17                 0
# 109          1.470       11000      0                6                 0
# 13           7.710       26000      0                8                 0
# 210          4.600       35775      0               11                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# ...

# %%
Y_train
# Out:
# 194    0.20
# 277    9.70
# 115    1.11
# 141    0.60
# 58     4.10
#        ...
# 24     2.90
# 85     2.50
# 109    1.20
# 13     6.10
# 210    3.10
# Name: Selling_Price, Length: 239, dtype: float64

# %%
X_test
# Out:
#      Present_Price  Kms_Driven  Owner  Number_of_years  Fuel_Type_Diesel  \
# 172           0.64       13700      0                9                 0
# 9             8.92       42367      0                8                 1
# 185           0.58        1900      0               15                 0
# 35            7.74       49998      0               12                 0
# 241           7.13       35866      1                8                 0
# 253           9.90       48000      0                9                 1
# 176           1.05       30000      0               12                 0
# 31            4.89       54200      0               12                 0
# 272          10.00       27600      0                8                 0
# 202           5.70       28200      0                8                 0
# 260          13.60       29223      0                7                 0
# 169           0.54       14000      0                8                 0
# ...

# %%
Y_test
# Out:
# 172     0.40
# 9       7.45
# 185     0.25
# 35      2.95
# 241     4.75
# 253     7.20
# 176     0.35
# 31      2.35
# 272     7.50
# 202     4.40
# 260     9.15
# 169     0.40
# 111     1.15
# 256    10.25
# 51     23.00
# 43      5.50
# 148     0.52
# 45      7.50
# 60      6.95
# 133     0.72
# 147     0.55
# 16      7.25
# 64     33.00
# 196     0.17
# 223     8.25
# 170     0.40
# 285     7.40
# 121     1.05
# 283     8.99
# 29      7.45
# 264     4.00
# 50     14.90
# 110     1.20
# 73      2.65
# 118     1.10
# 225     2.70
# 289    10.11
# 143     0.60
# 48      5.80
# 7       6.50
# 276     8.65
# 127     0.75
# 82     23.00
# 27      6.00
# 178     0.35
# 120     1.05
# 2       7.25
# 188     0.25
# 104     1.35
# 258     8.40
# 154     0.50
# 262     4.00
# 132     0.75
# 201     3.25
# 270     4.10
# 61      4.50
# 138     0.60
# 105     1.35
# 279     6.25
# 135     0.65
# Name: Selling_Price, dtype: float64

# %%
X_train.shape
# Out:
# (239, 8)

# %%
Y_train.shape
# Out:
# (239,)

# %%
X_test.shape
# Out:
# (60, 8)

# %%
Y_test.shape
# Out:
# (60,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
# hyper parameters
n_estimators=[int(x) for x in np.linspace(start =100, stop= 1200, num=12)]
n_estimators
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomizedSearchCV()
# number of trees present in random forest
n_estimators=[int(x) for x in np.linspace(start =100, stop= 1200, num=12)]

# %%
# number of features to consider at every split
max_features = ["auto", "sqrt"]

# %%
# maximum number of levels in a tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

# %%
# max_depth.append(None)
# minimum no. of splits required to split a node
min_samples_split = [2, 5, 10, 15, 100]

# %%
# minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# creating random grid
random_grid = {'n_estimators': n_estimators,
              'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_samples_split,
              'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# we use random grid to find the best hyperparameters
# first we need to create base model 
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, scoring = "neg_mean_squared_error", n_iter =10, cv =5, verbose = 2, random_state=42, n_jobs=1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.9s
# ...

# %%
# now we need to do predictions
predictions=rf_random.predict(X_test)
predictions
# Out:
# array([ 0.42292988,  6.95382931,  0.3670671 ,  3.87122617,  4.72961304,
#         5.75799238,  0.49574872,  2.91235693,  7.26520249,  5.13284042,
#        11.39398749,  0.42394856,  1.16226223, 11.04595685, 19.48229601,
#         5.52867313,  0.45609561,  6.9814892 ,  7.0966535 ,  0.67352582,
#         0.49955989,  7.38978088, 20.30231937,  0.22528141,  7.05325375,
#         0.61043609,  6.95935467,  1.16083086,  9.26637008,  7.27877684,
#         4.68939359, 18.73959065,  1.18012505,  3.3045302 ,  1.15323083,
#         2.95151947, 11.47845911,  0.57175022,  5.83492049,  6.62132677,
#        10.93590384,  0.64809045, 18.4979039 ,  5.27109212,  0.36582892,
#         0.86362002,  7.92486504,  0.378706  ,  1.2910692 , 10.93590384,
#         0.62306559,  4.66065942,  0.7066877 ,  2.8972304 ,  4.34827301,
#         5.55583805,  0.61172364,  1.17197838,  8.49747969,  0.43506696])

# %%
sns.distplot(Y_test-predictions)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
# this plot clearly shows that it is a normal distribution

# %%
plt.scatter(Y_test, predictions)

# %%
# the plot is linear above

# %%
# now open a file where we want to store the data

# %%
# dump information to that file
rf_random
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# we get one pickle file created in the environment, it is used for deployment

# %%
with open('RandomizedSearchCV_model.pkl', 'wb') as f:
    pickle.dump(rf_random, f)
